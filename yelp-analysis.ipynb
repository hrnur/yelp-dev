# %% [markdown]
# Hana Nur
#
# ## Retrieving, cleaning, and analyzing Yelp data using the Yelp Developers API.

# %% [markdown]
# Goals:
# 1. What is the average review rating for fast food restaurants in Washington, DC?
# 2. How does that compare to the average rating of McDonald's locations in DC?

# %% [markdown]
# ### Setup

# %%
# imports
import pandas as pd
import json, requests, os, dotenv

# %%
# set env variables
print(dotenv.load_dotenv())
API_KEY = os.getenv('API_KEY')
# Out:
# True

# %% [markdown]
# ### Get Data

# %%
# get useragent info for header
r = requests.get('https://httpbin.org/user-agent')
useragent = json.loads(r.text)['user-agent']

def get(root, endpoint, headers, parameters, path, size=50):
    '''
    Make get request to Yelp API for given endpoint. Will retrieve all data from
    query.

    INPUT:
        root (str): api root for request
        endpoint (str): api endpoint
        headers (dict): request header
        parameters (dict): request parameters
        path (dict): JSON path for data to create pd.DataFrame
        size (int): size of each page or data limit

    RETURN:
        pd.DataFrame of request output
    '''
    req = requests.get(root + endpoint, params=parameters, headers=headers)
    j = json.loads(req.text)
    df = pd.json_normalize(j, record_path=[path])
    if j['total'] > size:
        pages = round(j['total']/size)
        for page in range(1, pages):
            headers['offset'] = str(page*size)
            headers['offset']
            req = requests.get(root + endpoint, params=parameters, headers=headers)
            j = json.loads(req.text)
            temp = pd.json_normalize(j, record_path=[path])
            print(temp.name[0], headers['offset'])
            df = pd.concat([df, temp])
    return df

# %%
# make a request to the business search endpoint
# get data for all fast food businesses in Washington DC

root = 'https://api.yelp.com/v3'
endpoint = '/businesses/search'
header = {'User-Agent': useragent,
        'Authorization': f'Bearer {API_KEY}',
        'sort_by': 'Distance',
        'limit': '50'}
params = {
    'location': 'Washington, DC',
    'term': 'fast food'
}
path = 'businesses'
df = get(root, endpoint, header, params, path)
df
# Out:
# Raising Cane's 50
# Raising Cane's 100
# Raising Cane's 150
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/json/_normalize.py:400, in json_normalize.<locals>._pull_field(js, spec, extract_record)
#     399     else:
# --> 400         result = result[spec]
#     401 except KeyError as e:
#
# KeyError: 'businesses'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[138], line 15
#      10 params = {
#      11     'location': 'Washington, DC',
#      12     'term': 'fast food'
#      13 }
#      14 path = 'businesses'
# ---> 15 df = get(root, endpoint, header, params, path)
#      16 df
#
# Cell In[137], line 31, in get(root, endpoint, headers, parameters, path, size)
#      29 req = requests.get(root + endpoint, params=parameters, headers=headers)
#      30 j = json.loads(req.text)
# ---> 31 temp = pd.json_normalize(j, record_path=[path])
#      32 print(temp.name[0], headers['offset'])
#      33 df = pd.concat([df, temp])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/json/_normalize.py:519, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     516                 meta_vals[key].append(meta_val)
#     517             records.extend(recs)
# --> 519 _recursive_extract(data, record_path, {}, level=0)
#     521 result = DataFrame(records)
#     523 if record_prefix is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/json/_normalize.py:501, in json_normalize.<locals>._recursive_extract(data, path, seen_meta, level)
#     499 else:
#     500     for obj in data:
# --> 501         recs = _pull_records(obj, path[0])
#     502         recs = [
#     503             nested_to_record(r, sep=sep, max_level=max_level)
#     504             if isinstance(r, dict)
#     505             else r
#     506             for r in recs
#     507         ]
#     509         # For repeating the metadata later
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/json/_normalize.py:423, in json_normalize.<locals>._pull_records(js, spec)
#     417 def _pull_records(js: dict[str, Any], spec: list | str) -> list:
#     418     """
#     419     Internal function to pull field for records, and similar to
#     420     _pull_field, but require to return list. And will raise error
#     421     if has non iterable value.
#     422     """
# --> 423     result = _pull_field(js, spec, extract_record=True)
#     425     # GH 31507 GH 30145, GH 26284 if result is not list, raise TypeError if not
#     426     # null, otherwise return an empty list
#     427     if not isinstance(result, list):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/json/_normalize.py:403, in json_normalize.<locals>._pull_field(js, spec, extract_record)
#     401 except KeyError as e:
#     402     if extract_record:
# --> 403         raise KeyError(
#     404             f"Key {e} not found. If specifying a record_path, all elements of "
#     405             f"data should have the path."
#     406         ) from e
#     407     if errors == "ignore":
#     408         return np.nan
#
# KeyError: "Key 'businesses' not found. If specifying a record_path, all elements of data should have the path."

# %%
df.head(21)
# Out:
#                         id                                         alias  \
# 0   O_UtaytkTgvUfkY1Q8MqTg                      raising-canes-washington
# 1   gFxIqs_GjtqUfqg812ZA1Q                  honeymoon-chicken-washington
# 2   Hsv9yqJ8lOY3hP-VeQP0EQ                    surfside-dupont-washington
# 3   10-zwHrW7F0ckvYd_Fni0w                         swizzler-washington-4
# 4   ZbVNADWUpTAjbB79qeXtwg                        service-bar-washington
# 5   WTA0ediIX-3Vyyua6EWdSQ                   man-vs-fries-washington-d-c
# 6   2aI5hO7hBotYjNZIiI1FdQ                   yums-ii-carryout-washington
# 7   iqV-9rIC-azTw9OQQc8Vhw                    district-taco-washington-6
# 8   mhAC6aVjmMI1G5UNPk-tfA                       bub-and-pops-washington
# 9   bCQEdpKSY563iAzq7cMcGA               the-capital-burger-washington-6
# 10  o9ayRcEwrAIXf6vbybt7Mw  astro-doughnuts-and-fried-chicken-washington
# 11  7hUCL__O8xQt9Z5Uzndmtw                         eat-brgz-washington-2
# 12  m2-ttM4wZKm5tgjq4ovC3Q                   aladdins-kitchen-washington
# 13  7fnHl5OGmS1dhN1lQWpGcw                 nandos-peri-peri-washington-9
# 14  2lWxthDbB9ARyiMtp-TLgQ                  roaming-rooster-washington-6
# 15  asHUYVFnZZJr47xMscxsUw                jumbo-slice-pizza-washington-2
# 16  Sliw9LJz-_vhS2uuNsGQ-w         all-about-burger-chinatown-washington
# 17  QJMhG5YZa422Rqz-m_gXYw                  chicken-whiskey-washington-4
# 18  GGuUe6g72-1zsYOSmTPsMA    raising-canes-chicken-fingers-washington-2
# 19  Jcj1YF-oXOe4-t1pMIVGdQ                           chaia-washington-11
# 0   O_UtaytkTgvUfkY1Q8MqTg                      raising-canes-washington
#
#                                name  \
# 0                    Raising Cane's
# 1                 Honeymoon Chicken
# 2                   Surfside Dupont
# 3                          Swizzler
# 4                       Service Bar
# 5                      Man vs Fries
# 6                 Yum's II Carryout
# 7                     District Taco
# 8                     Bub and Pop's
# 9                The Capital Burger
# 10  Astro Doughnuts & Fried Chicken
# 11                         Eat Brgz
# 12                Aladdin's Kitchen
# 13                Nando's Peri-Peri
# 14                  Roaming Rooster
# 15                Jumbo Slice Pizza
# 16       All About Burger Chinatown
# 17                Chicken + Whiskey
# 18   Raising Cane's Chicken Fingers
# 19                            Chaia
# 0                    Raising Cane's
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/V3aZXH...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/qhRM9Q...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/z7MY5M...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/k4XKs4...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/l-oY-D...      False
# 5   https://s3-media1.fl.yelpcdn.com/bphoto/gfzQmo...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/146b2a...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/EHCDWb...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/CbVBw_...      False
# 9   https://s3-media1.fl.yelpcdn.com/bphoto/7NfKT0...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/JtF4QR...      False
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/8Ebpit...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/C57nSW...      False
# 13  https://s3-media1.fl.yelpcdn.com/bphoto/0fYs8L...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/NGqAwS...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/KxWtkD...      False
# 16  https://s3-media1.fl.yelpcdn.com/bphoto/_6iQNL...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/sCplMa...      False
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/zkIFAT...      False
# 19  https://s3-media2.fl.yelpcdn.com/bphoto/_lkVeg...      False
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/V3aZXH...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/raising-canes-washing...            14
# 1   https://www.yelp.com/biz/honeymoon-chicken-was...           380
# 2   https://www.yelp.com/biz/surfside-dupont-washi...           645
# 3   https://www.yelp.com/biz/swizzler-washington-4...           158
# 4   https://www.yelp.com/biz/service-bar-washingto...           283
# 5   https://www.yelp.com/biz/man-vs-fries-washingt...            18
# 6   https://www.yelp.com/biz/yums-ii-carryout-wash...           208
# 7   https://www.yelp.com/biz/district-taco-washing...          1794
# 8   https://www.yelp.com/biz/bub-and-pops-washingt...          1015
# 9   https://www.yelp.com/biz/the-capital-burger-wa...           886
# 10  https://www.yelp.com/biz/astro-doughnuts-and-f...          1353
# 11  https://www.yelp.com/biz/eat-brgz-washington-2...           105
# 12  https://www.yelp.com/biz/aladdins-kitchen-wash...           270
# 13  https://www.yelp.com/biz/nandos-peri-peri-wash...          1158
# 14  https://www.yelp.com/biz/roaming-rooster-washi...           158
# 15  https://www.yelp.com/biz/jumbo-slice-pizza-was...           277
# 16  https://www.yelp.com/biz/all-about-burger-chin...            17
# 17  https://www.yelp.com/biz/chicken-whiskey-washi...           641
# 18  https://www.yelp.com/biz/raising-canes-chicken...             3
# 19  https://www.yelp.com/biz/chaia-washington-11?a...           181
# 0   https://www.yelp.com/biz/raising-canes-washing...            14
#
#                                            categories  rating  \
# 0   [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     4.1
# 1   [{'alias': 'chickenshop', 'title': 'Chicken Sh...     4.0
# 2   [{'alias': 'tex-mex', 'title': 'Tex-Mex'}, {'a...     4.0
# 3   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 4   [{'alias': 'cocktailbars', 'title': 'Cocktail ...     4.3
# 5   [{'alias': 'fooddeliveryservices', 'title': 'F...     2.6
# 6   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.2
# 7          [{'alias': 'mexican', 'title': 'Mexican'}]     3.8
# 8   [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.4
# 9   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.3
# 10  [{'alias': 'donuts', 'title': 'Donuts'}, {'ali...     3.8
# 11  [{'alias': 'newamerican', 'title': 'New Americ...     4.2
# 12  [{'alias': 'halal', 'title': 'Halal'}, {'alias...     4.0
# 13  [{'alias': 'portuguese', 'title': 'Portuguese'...     3.8
# 14  [{'alias': 'chickenshop', 'title': 'Chicken Sh...     4.3
# 15  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.5
# 16  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.7
# 17  [{'alias': 'venezuelan', 'title': 'Venezuelan'...     4.2
# 18  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     4.0
# 19  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.4
# 0   [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     4.1
#
#           transactions  ... coordinates.longitude  \
# 0                   []  ...            -77.006210
# 1   [pickup, delivery]  ...            -77.025307
# 2           [delivery]  ...            -77.042319
# 3   [pickup, delivery]  ...            -77.006144
# 4   [pickup, delivery]  ...            -77.025010
# 5   [pickup, delivery]  ...            -77.021180
# 6             [pickup]  ...            -77.031757
# 7   [pickup, delivery]  ...            -77.030135
# 8   [pickup, delivery]  ...            -77.042368
# 9           [delivery]  ...            -77.021605
# 10  [pickup, delivery]  ...            -77.029940
# 11                  []  ...            -77.047723
# 12  [pickup, delivery]  ...            -77.041340
# 13  [pickup, delivery]  ...            -77.023579
# 14                  []  ...            -77.030583
# 15  [pickup, delivery]  ...            -77.041695
# 16  [pickup, delivery]  ...            -77.019083
# 17  [pickup, delivery]  ...            -77.032106
# 18                  []  ...            -77.005654
# 19  [pickup, delivery]  ...            -77.020993
# 0                   []  ...            -77.006210
#
#                location.address1  location.address2  location.address3  \
# 0        50 Massachusetts Ave NE                         Union Station
# 1            4201 Georgia Ave NW                                  None
# 2                   1800 N St NW
# 3                 1259 1st St SE                                  None
# 4                    928 U St NW                                  None
# 5                    631 P St NW               None               None
# 6                1413 14th St NW
# 7                   1309 F St NW
# 8                   1815 M St NW               None
# 9                 1005 7th St NW               None               None
# 10                  1308 G St NW
# 11     1200 New Hampshire Ave NW               None
# 12           1782 Florida Ave NW                                  None
# 13                   836 F St NW
# 14                  1301 U St NW                                  None
# 15               2341 18th St NW
# 16                   501 H St NW               None
# 17               1738 14th St NW                                  None
# 18  M143 50 Massachusetts Ave NE               None               None
# 19                   615 I St NW                                  None
# 0        50 Massachusetts Ave NE                         Union Station
#
#        location.city location.zip_code location.country location.state  \
# 0     Washington, DC             20002               US             DC
# 1     Washington, DC             20011               US             DC
# 2     Washington, DC             20036               US             DC
# 3     Washington, DC             20003               US             DC
# 4     Washington, DC             20001               US             DC
# 5   Washington, D.C.             20001               US             DC
# 6     Washington, DC             20005               US             DC
# 7     Washington, DC             20004               US             DC
# 8     Washington, DC             20036               US             DC
# 9     Washington, DC             20001               US             DC
# 10    Washington, DC             20005               US             DC
# 11    Washington, DC             20036               US             DC
# 12    Washington, DC             20009               US             DC
# 13    Washington, DC             20004               US             DC
# 14    Washington, DC             20009               US             DC
# 15    Washington, DC             20009               US             DC
# 16    Washington, DC             20001               US             DC
# 17    Washington, DC             20009               US             DC
# 18    Washington, DC             20002               US             DC
# 19    Washington, DC             20001               US             DC
# 0     Washington, DC             20002               US             DC
#
#                              location.display_address price
# 0   [50 Massachusetts Ave NE, Union Station, Washi...   NaN
# 1         [4201 Georgia Ave NW, Washington, DC 20011]    $$
# 2                [1800 N St NW, Washington, DC 20036]    $$
# 3              [1259 1st St SE, Washington, DC 20003]    $$
# 4                 [928 U St NW, Washington, DC 20001]    $$
# 5           [631 P St NW, Washington, D.C., DC 20001]   NaN
# 6             [1413 14th St NW, Washington, DC 20005]     $
# 7                [1309 F St NW, Washington, DC 20004]    $$
# 8                [1815 M St NW, Washington, DC 20036]    $$
# 9              [1005 7th St NW, Washington, DC 20001]    $$
# 10               [1308 G St NW, Washington, DC 20005]     $
# 11  [1200 New Hampshire Ave NW, Washington, DC 20036]    $$
# 12        [1782 Florida Ave NW, Washington, DC 20009]    $$
# 13                [836 F St NW, Washington, DC 20004]    $$
# 14               [1301 U St NW, Washington, DC 20009]   NaN
# 15            [2341 18th St NW, Washington, DC 20009]     $
# 16                [501 H St NW, Washington, DC 20001]   NaN
# 17            [1738 14th St NW, Washington, DC 20009]    $$
# 18  [M143 50 Massachusetts Ave NE, Washington, DC ...   NaN
# 19                [615 I St NW, Washington, DC 20001]   NaN
# 0   [50 Massachusetts Ave NE, Union Station, Washi...   NaN
#
# [21 rows x 24 columns]

# %% [markdown]
# ### Clean Data

# %%
df.isna().sum()
# Out:
# id                            0
# alias                         0
# name                          0
# image_url                     0
# is_closed                     0
# url                           0
# review_count                  0
# categories                    0
# rating                        0
# transactions                  0
# phone                         0
# display_phone                 0
# distance                      0
# coordinates.latitude          0
# coordinates.longitude         0
# location.address1             0
# location.address2           252
# location.address3           360
# location.city                 0
# location.zip_code             0
# location.country              0
# location.state                0
# location.display_address      0
# price                       216
# dtype: int64

# %%
# address2 and address3 are unnecessary
# dropping cols to remove NA values
df = df.drop(['location.address2', 'location.address3'], axis=1)

# %% [markdown]
# ### Analyze Data

# %% [markdown]
# ##### What is the average review rating for fast food restaurants in Washington, DC?

# %%
df.rating.mean()
# Out:
# 4.0

# %% [markdown]
# ##### How does that compare to the average rating of McDonald's locations in DC?

# %%
df['name'].value_counts()
# Out:
# name
# Raising Cane's                     36
# Honeymoon Chicken                  36
# Chicken + Whiskey                  36
# Raising Cane's Chicken Fingers     36
# All About Burger Chinatown         36
# Aladdin's Kitchen                  36
# Roaming Rooster                    36
# Nando's Peri-Peri                  36
# Eat Brgz                           36
# Astro Doughnuts & Fried Chicken    36
# Bub and Pop's                      36
# The Capital Burger                 36
# District Taco                      36
# Yum's II Carryout                  36
# Man vs Fries                       36
# Z-Burger                           36
# Service Bar                        36
# Swizzler                           36
# Surfside Dupont                    36
# Chaia                              36
# Name: count, dtype: int64
